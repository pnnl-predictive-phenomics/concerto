# %% [markdown]
# # Create a csv file in the format that memote will accept (experiments.yml) to run
# - ASK: what is the purpose of rich media vs minimal media--what differences do we anticipate, and how does that help the community model
# - ASK: where does exchange/uptake happen int he model (how do we know that this is the result of an exchange or an uptake of metabolites)
# - Requires running of carve.me model generation first

# %%
#We load the necessary libraries.
import pandas as pd
import re
import cobra
from cobra.io import read_sbml_model
from cobra.medium import minimal_medium

#We load the model that we want to generate a minimal media csv file.
model_csc031 = read_sbml_model("concerto/concerto/memotedata/updated_modelcsc031FixedCompartments.xml")

def getMedias(model, element, model_name):
    '''
    PARAMETERS:
    model: The model that you want to generate the rich media csv file.
    element: The element you want to exclude from the csv file (not necessary for getting the rich media.)
    model_name: A string whos only purpose is to help rename the new generated csv file.'''
    
    Info = "exchange,uptake\n" #We create a string that will contain the information that we want to extract from the model.
    for medium in model.medium: #We iterate trough each of the exchange reactions found in the model.
        #print(type(medium))
        reaction = model.reactions.get_by_id(medium) #We extract the exchange reaaction and store it on a variable.
        Info = Info + medium + ",1000\n" #We concatenate each of the exchange reaction with an uptake of 1000.
        #print(medium)
        #print(reaction.metabolites)
        #print(reaction)
        #for metabolite in reaction.metabolites:
            #print(metabolite)
            #print(metabolite.formula)
            #print(element)
            #print("____")
            #if not re.search(element, metabolite.formula): #UNCOMMENT THIS PART TO FILTER THROUGH A SPECIFIC ELEMENT.
                #Info = Info + medium + "," + "1000\n"
                #print(Info)
                #print(metabolite)
                #print(metabolite.formula)
    newfile = open(str(model_name) + str(element) + "-less_mediaRichMedia.csv", "w")
    newfile.write(Info)
    return #print(Info) # UNCOMMENT THIS PRINT TO SEE THE CONTENTS OF THE CSV FILE.

getMedias(model_csc031, "C", "csc031") #filters through for reaction in Carbon
# Out:
# '' is not a valid SBML 'SId'.
# exchange,uptake
# EX_25dkglcn_e,1000
# EX_2m35mdntha_e,1000
# EX_34dhpac_e,1000
# EX_35dnta_e,1000
# EX_4abut_e,1000
# EX_4ahmmp_e,1000
# EX_4hbz_e,1000
# EX_4hphac_e,1000
# EX_4hpro_LT_e,1000
# EX_4oxptn_e,1000
# EX_5drib_e,1000
# EX_LalaDgluMdap_e,1000
# EX_LalaLglu_e,1000
# EX_Larab_e,1000
# EX_Lcyst_e,1000
# EX_abg4_e,1000
# EX_ac_e,1000
# EX_acald_e,1000
# EX_acgam_e,1000
# EX_acmana_e,1000
# EX_acnam_e,1000
# EX_acon_C_e,1000
# EX_adn_e,1000
# EX_akg_e,1000
# EX_ala_B_e,1000
# EX_ala_L_asp__L_e,1000
# EX_ala_L_glu__L_e,1000
# EX_ala_L_thr__L_e,1000
# EX_ala__D_e,1000
# EX_ala__L_e,1000
# EX_ala_gln_e,1000
# EX_ala_his_e,1000
# EX_ala_leu_e,1000
# EX_alagly_e,1000
# EX_alahis_e,1000
# EX_alaleu_e,1000
# EX_alathr_e,1000
# EX_alatrp_e,1000
# EX_anhgm_e,1000
# EX_arab__L_e,1000
# EX_arbt6p_e,1000
# EX_arbt_e,1000
# EX_arg__L_e,1000
# EX_ascb__L_e,1000
# EX_asn__L_e,1000
# EX_asp__L_e,1000
# EX_balaala_e,1000
# EX_balabala_e,1000
# EX_balagly_e,1000
# EX_balaleu_e,1000
# EX_balamd_e,1000
# EX_bz_e,1000
# EX_bzalc_e,1000
# EX_ca2_e,1000
# EX_carn_e,1000
# EX_cellb_e,1000
# EX_cgly_e,1000
# EX_ch4s_e,1000
# EX_chol_e,1000
# EX_chols_e,1000
# EX_chsterol_e,1000
# EX_cinnm_e,1000
# EX_cit_e,1000
# EX_cl_e,1000
# EX_cmcbtt_e,1000
# EX_co2_e,1000
# EX_cobalt2_e,1000
# EX_crn_e,1000
# EX_csn_e,1000
# EX_cu2_e,1000
# EX_cyan_e,1000
# EX_cytd_e,1000
# EX_dca_e,1000
# EX_dopa_e,1000
# EX_drib_e,1000
# EX_duri_e,1000
# EX_dxyl_e,1000
# EX_enter_e,1000
# EX_etoh_e,1000
# EX_fe2_e,1000
# EX_fe3_e,1000
# EX_fe3dcit_e,1000
# EX_fe3pyovd_kt_e,1000
# EX_feenter_e,1000
# EX_for_e,1000
# EX_fru_e,1000
# EX_fuc_e,1000
# EX_fum_e,1000
# EX_g3pc_e,1000
# EX_g3pe_e,1000
# EX_g3pg_e,1000
# EX_gal_bD_e,1000
# EX_galctn__D_e,1000
# EX_galman4_e,1000
# EX_galman6_e,1000
# EX_galt_e,1000
# EX_gam_e,1000
# EX_glc__D_e,1000
# EX_glc__aD_e,1000
# EX_glcman4_e,1000
# EX_glcman6_e,1000
# EX_gln__L_e,1000
# EX_glu__L_e,1000
# EX_glucan4_e,1000
# EX_glucan6_e,1000
# EX_gly_asn__L_e,1000
# EX_gly_asp__L_e,1000
# EX_gly_cys_e,1000
# EX_gly_e,1000
# EX_gly_gln_e,1000
# EX_gly_glu__L_e,1000
# EX_gly_leu_e,1000
# EX_gly_met_e,1000
# EX_gly_phe_e,1000
# EX_gly_pro__L_e,1000
# EX_gly_tyr_e,1000
# EX_glyald_e,1000
# EX_glyb_e,1000
# EX_glyc3p_e,1000
# EX_glyc_e,1000
# EX_glyclt_e,1000
# EX_glygln_e,1000
# EX_glyglu_e,1000
# EX_glygly_e,1000
# EX_glyglygln_e,1000
# EX_glymet_e,1000
# EX_glyphe_e,1000
# EX_glyser_e,1000
# EX_gthrd_e,1000
# EX_gua_e,1000
# EX_h2o2_e,1000
# EX_h2o_e,1000
# EX_h2s_e,1000
# EX_h_e,1000
# EX_hco3_e,1000
# EX_hdca_e,1000
# EX_hexs_e,1000
# EX_hia_e,1000
# EX_his__L_e,1000
# EX_hisgly_e,1000
# EX_hishis_e,1000
# EX_hom__L_e,1000
# EX_hpta_e,1000
# EX_hxa_e,1000
# EX_hxan_e,1000
# EX_icit_e,1000
# EX_ile__L_e,1000
# EX_ind3ac_e,1000
# EX_indole_e,1000
# EX_inost_e,1000
# EX_k_e,1000
# EX_lac__L_e,1000
# EX_lcts_e,1000
# EX_leu__L_e,1000
# EX_leuleu_e,1000
# EX_lmn2_e,1000
# EX_lnlc_e,1000
# EX_lys__L_e,1000
# EX_lysglugly_e,1000
# EX_mal__L_e,1000
# EX_malt_e,1000
# EX_malthp_e,1000
# EX_malthx_e,1000
# EX_malttr_e,1000
# EX_maltttr_e,1000
# EX_man_e,1000
# EX_manb_e,1000
# EX_mantr_e,1000
# EX_manttr_e,1000
# EX_meoh_e,1000
# EX_met_L_ala__L_e,1000
# EX_met__L_e,1000
# EX_metox__R_e,1000
# EX_metox_e,1000
# EX_metsox_R__L_e,1000
# EX_metsox_S__L_e,1000
# EX_mg2_e,1000
# EX_mn2_e,1000
# EX_mnl_e,1000
# EX_mso3_e,1000
# EX_nac_e,1000
# EX_nh4_e,1000
# EX_nmn_e,1000
# EX_no2_e,1000
# EX_no3_e,1000
# EX_no_e,1000
# EX_nona_e,1000
# EX_o2_e,1000
# EX_ocdca_e,1000
# EX_octa_e,1000
# EX_orn_e,1000
# EX_pdima_e,1000
# EX_peamn_e,1000
# EX_pentso3_e,1000
# EX_phe__L_e,1000
# EX_phedca_e,1000
# EX_phehpa_e,1000
# EX_phehxa_e,1000
# EX_pheme_e,1000
# EX_phenona_e,1000
# EX_pheocta_e,1000
# EX_phept_e,1000
# EX_pi_e,1000
# EX_pnto__R_e,1000
# EX_pro__L_e,1000
# EX_progly_e,1000
# EX_prohisglu_e,1000
# EX_pta_e,1000
# EX_ptrc_e,1000
# EX_ptsla_e,1000
# EX_pyovd_kt_e,1000
# EX_raffin_e,1000
# EX_rbt_e,1000
# EX_rib__D_e,1000
# EX_rmn_e,1000
# EX_salc_e,1000
# EX_salchs4_e,1000
# EX_salchs4fe_e,1000
# EX_sbt__D_e,1000
# EX_sel_e,1000
# EX_ser__D_e,1000
# EX_ser__L_e,1000
# EX_serglugly_e,1000
# EX_skm_e,1000
# EX_slnt_e,1000
# EX_so3_e,1000
# EX_so4_e,1000
# EX_spmd_e,1000
# EX_succ_e,1000
# EX_sucr_e,1000
# EX_taur_e,1000
# EX_tcynt_e,1000
# EX_thm_e,1000
# EX_thr__L_e,1000
# EX_tnt_e,1000
# EX_tre_e,1000
# EX_trp__L_e,1000
# EX_tsul_e,1000
# EX_ttdca_e,1000
# EX_tyr__L_e,1000
# EX_ump_e,1000
# EX_ura_e,1000
# EX_uri_e,1000
# EX_val__L_e,1000
# EX_vanlt_e,1000
# EX_xyl3_e,1000
# EX_xyl__D_e,1000
# EX_xylan4_e,1000
# EX_xylb_e,1000
# EX_xylu__L_e,1000
# EX_zn2_e,1000
# EX_cs_c_e,1000
# EX_dextrin_e,1000
# EX_glycogen_e,1000
# EX_mannan_e,1000
# EX_pectin_e,1000
# EX_acgal_e,1000
# EX_arab__D_e,1000
# EX_abt__D_e,1000
# EX_abt__L_e,1000
# EX_madg_e,1000
# EX_pala_e,1000
# EX_salcn_e,1000
# EX_srb__L_e,1000
# EX_stys_e,1000
# EX_tag__D_e,1000
# EX_xylt_e,1000
# EX_but_e,1000
# EX_citac_e,1000
# EX_citm_e,1000
# EX_itacon_e,1000
# EX_5dglcn_e,1000
# EX_malon_e,1000
# EX_oxa_e,1000
# EX_quin_e,1000
# EX_Dara14lac_e,1000
# EX_sebacid_e,1000
# EX_tartr__D_e,1000
# EX_tartr__L_e,1000
# EX_ad_e,1000
# EX_acglu_e,1000
# EX_4hpro_DC_e,1000
# EX_orn__L_e,1000
# EX_5oxpro_e,1000
# EX_dha_e,1000
# EX_btd_RR_e,1000
# EX_diact_e,1000
# EX_R_actn_e,1000
# EX_atp_e,1000
# EX_ctp_e,1000
# EX_gtp_e,1000
# EX_utp_e,1000
# EX_itp_e,1000
# EX_nadh_e,1000
# EX_fadh2_e,1000
# EX_rbflvrd_e,1000
# EX_mql8_e,1000
# EX_mql6_e,1000
# EX_mql7_e,1000
# EX_2dmmql8_e,1000
# EX_accoa_e,1000
